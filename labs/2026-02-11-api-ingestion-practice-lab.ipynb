# %% [markdown]
# # API Exploration Notebook
#
# This notebook demonstrates how to work with two public APIs:
#
# 1. **SuperHero API**[](https://superheroapi.com/) — superhero character data (powerstats, biography, etc.)
# 2. **YH Finance API** (via https://financeapi.net/) — real-time & historical stock, ETF, crypto data
#
# Goals:
# - Understand API authentication (tokens / headers)
# - Fetch data using requests
# - Parse JSON responses
# - Perform ETL (Extract → Transform → Load into pandas DataFrames)
# - Basic analysis and visualization
#
# **Prerequisites**
# - SuperHero API: Sign up with GitHub at https://superheroapi.com/ to get an access token
# - YH Finance API: Register at https://financeapi.net/ to get an API key (free tier available)

# %% [markdown]
# ## 1. Imports & Setup

# %%
import requests
import json
import pandas as pd
import matplotlib.pyplot as plt
from pprint import pprint
from datetime import datetime
import time  # for optional rate limiting

# ────────────────────────────────────────────────
# SUPERHERO API CONFIG
SUPERHERO_TOKEN = "token"  # from https://superheroapi.com/
SUPERHERO_BASE = f"https://superheroapi.com/api/{SUPERHERO_TOKEN}"

# ────────────────────────────────────────────────
# YH FINANCE API CONFIG
FINANCE_API_KEY = "token"      # from https://financeapi.net/dashboard
FINANCE_BASE = "https://yfapi.net"
FINANCE_HEADERS = {"X-API-KEY": FINANCE_API_KEY}     # Key MUST be in headers

# %% [markdown]
# ## Part A: SuperHero API
#
# Fetch character profiles, powerstats, biography, and build comparisons.

# %% [markdown]
# ### A.1 Test Connection (Batman – ID 70)

# %%
test_url = f"{SUPERHERO_BASE}/70"
resp = requests.get(test_url)

if resp.status_code == 200:
    data = resp.json()
    print("SuperHero API working! Keys:", list(data.keys()))
    pprint(data, indent=2)
else:
    print("Error:", resp.status_code, resp.text)
# Out:
# SuperHero API working! Keys: ['response', 'id', 'name', 'powerstats', 'biography', 'appearance', 'work', 'connections', 'image']
# { 'appearance': { 'eye-color': 'blue',
#                   'gender': 'Male',
#                   'hair-color': 'black',
#                   'height': ["6'2", '188 cm'],
#                   'race': 'Human',
#                   'weight': ['210 lb', '95 kg']},
#   'biography': { 'aliases': ['Insider', 'Matches Malone'],
#                  'alignment': 'good',
#                  'alter-egos': 'No alter egos found.',
#                  'first-appearance': 'Detective Comics #27',
#                  'full-name': 'Bruce Wayne',
#                  'place-of-birth': 'Crest Hill, Bristol Township; Gotham '
#                                    'County',
#                  'publisher': 'DC Comics'},
#   'connections': { 'group-affiliation': 'Batman Family, Batman Incorporated, '
#                                         'Justice League, Outsiders, Wayne '
#                                         'Enterprises, Club of Heroes, formerly '
#                                         'White Lantern Corps, Sinestro Corps',
#                    'relatives': 'Damian Wayne (son), Dick Grayson (adopted '
#                                 'son), Tim Drake (adopted son), Jason Todd '
#                                 '(adopted son), Cassandra Cain (adopted ward)\n'
#                                 'Martha Wayne (mother, deceased), Thomas Wayne '
#                                 '(father, deceased), Alfred Pennyworth (former '
#                                 'guardian), Roderick Kane (grandfather, '
#                                 'deceased), Elizabeth Kane (grandmother, '
#                                 'deceased), Nathan Kane (uncle, deceased), '
#                                 'Simon Hurt (ancestor), Wayne Family'},
#   'id': '70',
#   'image': { 'url': 'https://www.superherodb.com/pictures2/portraits/10/100/639.jpg'},
#   'name': 'Batman',
#   'powerstats': { 'combat': '100',
#                   'durability': '50',
#                   'intelligence': '100',
#                   'power': '47',
#                   'speed': '27',
#                   'strength': '26'},
#   'response': 'success',
#   'work': { 'base': 'Batcave, Stately Wayne Manor, Gotham City; Hall of '
#                     'Justice, Justice League Watchtower',
#             'occupation': 'Businessman'}}

# %% [markdown]
# ### A.2 Helper: Get Character by ID

# %%
def get_hero_by_id(hero_id):
    url = f"{SUPERHERO_BASE}/{hero_id}"
    resp = requests.get(url)
    if resp.status_code == 200:
        data = resp.json()
        if data.get('response') == 'success':
            return data
    print(f"Error fetching hero {hero_id}: {resp.status_code}")
    return None

# %% [markdown]
# ### A.3 Collect Multiple Heroes into DataFrame (ETL)

# %%
hero_ids = [70, 149, 332, 620]  # Batman, Captain America, Hulk, Spider-Man
heroes_data = []

for hid in hero_ids:
    hero = get_hero_by_id(hid)
    if hero:
        row = {
            'id': hero['id'],
            'name': hero['name'],
            'full_name': hero['biography'].get('full-name', 'N/A'),
            'publisher': hero['biography'].get('publisher', 'N/A'),
            'alignment': hero['biography'].get('alignment', 'N/A'),
            'intelligence': int(hero['powerstats'].get('intelligence', 0)),
            'strength':     int(hero['powerstats'].get('strength', 0)),
            'speed':        int(hero['powerstats'].get('speed', 0)),
            'durability':   int(hero['powerstats'].get('durability', 0)),
            'power':        int(hero['powerstats'].get('power', 0)),
            'combat':       int(hero['powerstats'].get('combat', 0)),
        }
        heroes_data.append(row)
    time.sleep(0.5)  # polite delay

df_heroes = pd.DataFrame(heroes_data)
df_heroes
# Out:
#     id             name     full_name      publisher alignment  intelligence  \
# 0   70           Batman   Bruce Wayne      DC Comics      good           100
# 1  149  Captain America  Steve Rogers  Marvel Comics      good            69
# 2  332             Hulk  Bruce Banner  Marvel Comics      good            88
# 3  620       Spider-Man  Peter Parker  Marvel Comics      good            90
#
#    strength  speed  durability  power  combat
# 0        26     27          50     47     100
# 1        19     38          55     60     100
# 2       100     63         100     98      85
# 3        55     67          75     74      85

# %% [markdown]
# ### A.4 Visualization: Powerstats Comparison

# %%
power_cols = ['intelligence', 'strength', 'speed', 'durability', 'power', 'combat']

df_heroes.plot(x='name', y=power_cols, kind='bar', figsize=(10,6))
plt.title('Superhero Powerstats Comparison')
plt.ylabel('Score (0–100)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Part B: YH Finance API (Stock Market Data)
#
# Fetch quotes, historical prices, fundamentals — requires API key in headers.

# %% [markdown]
# ### B.1 Test Connection (AAPL quote)

# %%
test_url = f"{FINANCE_BASE}/v6/finance/quote"
params = {"symbols": "AAPL"}

resp = requests.get(test_url, headers=FINANCE_HEADERS, params=params)

if resp.status_code == 200:
    data = resp.json()
    print("Finance API working! Keys:", list(data.keys()))
    pprint(data, indent=2)
else:
    print("Error:", resp.status_code, resp.text)
# Out:
# Finance API working! Keys: ['quoteResponse']
# { 'quoteResponse': { 'error': None,
#                      'result': [ { 'ask': 277.98,
#                                    'askSize': 4,
#                                    'averageAnalystRating': '2.0 - Buy',
#                                    'averageDailyVolume10Day': 61223380,
#                                    'averageDailyVolume3Month': 47922444,
#                                    'bid': 275.94,
#                                    'bidSize': 1,
#                                    'bookValue': 5.998,
#                                    'corporateActions': [],
#                                    'cryptoTradeable': False,
#                                    'currency': 'USD',
#                                    'customPriceAlertConfidence': 'HIGH',
#                                    'displayName': 'Apple',
#                                    'dividendDate': 1770854400,
#                                    'dividendRate': 1.04,
#                                    'dividendYield': 0.38,
#                                    'earningsCallTimestampEnd': 1769724000,
#                                    'earningsCallTimestampStart': 1769724000,
#                                    'earningsTimestamp': 1769720400,
#                                    'earningsTimestampEnd': 1777582800,
#                                    'earningsTimestampStart': 1777582800,
#                                    'epsCurrentYear': 8.47429,
#                                    'epsForward': 9.29181,
#                                    'epsTrailingTwelveMonths': 7.91,
#                                    'esgPopulated': False,
#                                    'exchange': 'NMS',
#                                    'exchangeDataDelayedBy': 0,
#                                    'exchangeTimezoneName': 'America/New_York',
#                                    'exchangeTimezoneShortName': 'EST',
#                                    'fiftyDayAverage': 268.5778,
#                                    'fiftyDayAverageChange': 7.992218,
#                                    'fiftyDayAverageChangePercent': 0.029757554,
#                                    'fiftyTwoWeekChangePercent': 15.540171,
#                                    'fiftyTwoWeekHigh': 288.62,
#                                    'fiftyTwoWeekHighChange': -12.049988,
#                                    'fiftyTwoWeekHighChangePercent': -0.041750357,
#                                    'fiftyTwoWeekLow': 169.21,
#                                    'fiftyTwoWeekLowChange': 107.36,
#                                    'fiftyTwoWeekLowChangePercent': 0.63447785,
#                                    'fiftyTwoWeekRange': '169.21 - 288.62',
#                                    'financialCurrency': 'USD',
#                                    'firstTradeDateMilliseconds': 345479400000,
#                                    'forwardPE': 29.764923,
#                                    'fullExchangeName': 'NasdaqGS',
#                                    'gmtOffSetMilliseconds': -18000000,
#                                    'hasPrePostMarketData': True,
#                                    'isEarningsDateEstimate': True,
#                                    'language': 'en-US',
#                                    'longName': 'Apple Inc.',
#                                    'market': 'us_market',
#                                    'marketCap': 4065005404160,
#                                    'marketState': 'REGULAR',
#                                    'messageBoardId': 'finmb_24937',
#                                    'priceEpsCurrentYear': 32.636364,
#                                    'priceHint': 2,
#                                    'priceToBook': 46.11037,
#                                    'quoteSourceName': 'Nasdaq Real Time Price',
#                                    'quoteType': 'EQUITY',
#                                    'region': 'US',
#                                    'regularMarketChange': 2.8900146,
#                                    'regularMarketChangePercent': 1.0559832,
#                                    'regularMarketDayHigh': 277.44,
#                                    'regularMarketDayLow': 274.45,
#                                    'regularMarketDayRange': '274.45 - 277.44',
#                                    'regularMarketOpen': 274.695,
#                                    'regularMarketPreviousClose': 273.68,
#                                    'regularMarketPrice': 276.57,
#                                    'regularMarketTime': 1770823574,
#                                    'regularMarketVolume': 12064628,
#                                    'sharesOutstanding': 14681140000,
#                                    'shortName': 'Apple Inc.',
#                                    'sourceInterval': 15,
#                                    'symbol': 'AAPL',
#                                    'tradeable': False,
#                                    'trailingAnnualDividendRate': 1.03,
#                                    'trailingAnnualDividendYield': 0.0037635195,
#                                    'trailingPE': 34.964603,
#                                    'triggerable': True,
#                                    'twoHundredDayAverage': 239.2472,
#                                    'twoHundredDayAverageChange': 37.322815,
#                                    'twoHundredDayAverageChangePercent': 0.15600106,
#                                    'typeDisp': 'Equity'}]}}

# %% [markdown]
# ### B.2 Helper: Get Real-time Quotes

# %%
def get_stock_quotes(symbols_str):
    url = f"{FINANCE_BASE}/v6/finance/quote"
    params = {"symbols": symbols_str}
    resp = requests.get(url, headers=FINANCE_HEADERS, params=params)
    if resp.status_code == 200:
        return resp.json().get('quoteResponse', {}).get('result', [])
    print(f"Quote error: {resp.status_code}")
    return []

# %% [markdown]
# ### B.3 Helper: Get Historical Data

# %%
def get_historical(symbol, range_="1mo", interval="1d"):
    url = f"{FINANCE_BASE}/v8/finance/chart/{symbol}"
    params = {"range": range_, "interval": interval}
    resp = requests.get(url, headers=FINANCE_HEADERS, params=params)
    if resp.status_code == 200:
        result = resp.json().get('chart', {}).get('result', [{}])[0]
        ts = result.get('timestamp', [])
        quote = result.get('indicators', {}).get('quote', [{}])[0]
        df = pd.DataFrame({
            'date': [datetime.fromtimestamp(t) for t in ts],
            'open': quote.get('open', []),
            'high': quote.get('high', []),
            'low': quote.get('low', []),
            'close': quote.get('close', []),
            'volume': quote.get('volume', [])
        })
        return df
    print(f"History error for {symbol}: {resp.status_code}")
    return pd.DataFrame()

# %% [markdown]
# ### B.4 ETL: Multiple Stocks into DataFrame

# %%
stocks = "AAPL,MSFT,GOOGL,NVDA"
quotes = get_stock_quotes(stocks)

stock_rows = []
for q in quotes:
    row = {
        'symbol': q.get('symbol'),
        'name': q.get('longName', 'N/A'),
        'price': q.get('regularMarketPrice'),
        'change_pct': q.get('regularMarketChangePercent'),
        'volume': q.get('regularMarketVolume'),
        'market_cap': q.get('marketCap')
    }
    stock_rows.append(row)

df_stocks = pd.DataFrame(stock_rows)
df_stocks['market_cap_billions'] = (df_stocks['market_cap'] / 1e9).round(2)
df_stocks = df_stocks.sort_values('market_cap_billions', ascending=False)
df_stocks
# Out:
#   symbol                   name     price  change_pct    volume  \
# 3   NVDA     NVIDIA Corporation  189.2124    0.356640  45032117
# 0   AAPL             Apple Inc.  276.5800    1.059629  12066438
# 2  GOOGL          Alphabet Inc.  312.2600   -1.983796   8736921
# 1   MSFT  Microsoft Corporation  403.6040   -2.338903  10335104
#
#       market_cap  market_cap_billions
# 3  4606754553856              4606.75
# 0  4065152204800              4065.15
# 2  3777409581056              3777.41
# 1  2999737384960              2999.74

# %% [markdown]
# ### B.5 Visualization: Stock Prices & Historical Trend

# %%
# Bar chart – current prices
df_stocks.plot(x='symbol', y='price', kind='bar', figsize=(8,5), color='teal')
plt.title('Current Stock Prices')
plt.ylabel('Price (USD)')
plt.show()

# Historical example – AAPL last month
df_aapl_hist = get_historical("AAPL")
if not df_aapl_hist.empty:
    df_aapl_hist.set_index('date')['close'].plot(figsize=(10,6), title='AAPL – 1 Month Close Price')
    plt.ylabel('Close Price (USD)')
    plt.show()

# %% [markdown]
# ## Conclusion
#
# We’ve now worked with two very different APIs:
#
# - **SuperHero API** — token in URL path, JSON → structured DataFrame → powerstats viz
# - **YH Finance API** — API key in headers, real-time + time-series data → ETL pipeline
#
# Next steps could include:
# - Error handling & retries
# - Merging superhero “strength” with fictional stock tickers 😄
# - Exporting DataFrames to CSV
# - More endpoints (options chains, quote summary modules, superhero search)
#
# Don’t forget to replace both tokens/keys before running!
